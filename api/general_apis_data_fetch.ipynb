# %% [markdown]
# # Get Jobs Data

# %% [markdown]
# #### Source

# %%
import requests
import json
from os import getenv

api_key = getenv("KEY")
api_endpoint = "https://..."

headers = {
    "apikey": api_key,
    "Content-Type": "application/json"
}
body = {
    "": "",
    "": ""
}

url = api_endpoint
response = requests.post(url, headers=headers, json=body)
response.raise_for_status()
page_results = response.json()

# %% [markdown]
# # Save data to local database

# %%
import psycopg2
from os import getenv

database_user = getenv("DB_USER")
database_password = getenv("DB_PASSWORD")
HOST = "localhost"
DATABASE = "market_fit"

conn = psycopg2.connect(
    host=HOST,
    database=DATABASE,
    user=database_user,
    password=database_password
)

cur = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import psycopg2
#       3 from datetime import datetime
# ----> 5 database_user = getenv("DB_USER")
#       6 database_password = getenv("DB_PASSWORD")
#       8 conn = psycopg2.connect(
#       9     host="localhost",
#      10     database="market_fit",
#      11     user=database_user,
#      12     password=database_password
#      13 )
#
# NameError: name 'getenv' is not defined
